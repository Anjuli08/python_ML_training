# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid = cv2.VideoCapture(0)
vid
# Out:
# <VideoCapture 000001FFB52776F0>

# %%
vid.isOpened()
# Out:
# True

# %%
k = vid.read()

# %%
type(k), len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[ 66,  38, 101],
#          [ 66,  35,  99],
#          [ 73,  38, 102],
#          ...,
#          [243, 245, 243],
#          [242, 244, 244],
#          [241, 244, 245]],
#
#         [[ 64,  33, 101],
#          [ 65,  33, 101],
#          [ 74,  38, 106],
#          ...,
#          [243, 245, 243],
#          [242, 244, 244],
#          [243, 245, 245]],
#
#         [[ 62,  27, 104],
#          [ 65,  29, 105],
#          [ 75,  36, 111],
#          ...,
#          [242, 244, 241],
#          [242, 244, 242],
#          [243, 244, 244]],
#
#         ...,
#
#         [[ 86,  45,  49],
#          [ 88,  46,  50],
#          [ 89,  47,  51],
#          ...,
#          [226, 221, 220],
#          [228, 221, 221],
#          [228, 221, 222]],
#
#         [[ 91,  48,  52],
#          [ 89,  46,  50],
#          [ 89,  45,  48],
#          ...,
#          [225, 219, 219],
#          [227, 220, 221],
#          [228, 221, 222]],
#
#         [[ 91,  47,  51],
#          [ 90,  46,  50],
#          [ 90,  46,  49],
#          ...,
#          [225, 219, 220],
#          [226, 219, 220],
#          [227, 219, 222]]], dtype=uint8))

# %%
flag, img = vid.read()

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
if flag:
    plt.imshow(img[:,:,::-1])

# %%
if flag:
    plt.imshow(img[:,::-1,::-1])

# %%
for i in range(100):
    flag, img = vid.read()
    if flag:
        cv2.imshow('preview', img)
        cv2.waitKey(1)

# %%
for i in range(100):
    flag, img = vid.read()
    if flag:
        cv2.imshow('preview', img)
        cv2.waitKey(1)
vid.release()     #camera off   
cv2.destroyAllWindows()

# %%
for i in range(100):
    flag, img = vid.read()
    if flag:
        cv2.imshow('preview', img)
        key = cv2.waitKey(1)
        if key == ord('x'):
            break
vid.release()     #camera off   
cv2.destroyAllWindows()
# Out:
# -1

# %%
import cv2
from time import sleep

vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        cv2.imshow('preview', img_gray)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        break  
    sleep(0.1)  
vid.release()     #camera off   
cv2.destroyAllWindows()

# %%
import cv2

from time import sleep

fd = cv2.CascadeClassifier(
    cv2.data.haarcascades +
    'haarcascade_frontalface_default.xml'
    )
vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        x1, y1, w, h = (200, 400, 300, 400)
        faces = fd.detectMultiScale(img_gray, 1.1, 5)

        for x1,y1,w,h in faces:
            
            img_cropped = img[y1:y1+h, x1:x1+w, :]
            
            cv2.rectangle(
                img,
                pt1=(x1,y1), pt2=(x1+w, y1+h),
                color=(0,0,255), thickness=5
                )

        cv2.imshow('preview', img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        break  
    sleep(0.1)  
vid.release()     #camera off   
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from time import sleep

fd = cv2.CascadeClassifier(
    cv2.data.haarcascades +
    'haarcascade_frontalface_default.xml'
    )
vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        x1, y1, w, h = (200, 400, 300, 400)
        faces = fd.detectMultiScale(img_gray, 1.1, 5)
        
        for x1,y1,w,h in faces:
            
            img_cropped = img[y1:y1+h, x1:x1+w, :]
            
            cv2.rectangle(
                img,
                pt1=(x1,y1), pt2=(x1+w, y1+h),
                color=list(np.random.random(size=3) * 256), thickness=5
                )

        cv2.imshow('preview', img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        break  
    sleep(0.1)  
vid.release()     #camera off   
cv2.destroyAllWindows()
